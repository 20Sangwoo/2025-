# %%
fruits = 'blueberry'

# %%
fruits[:]
# Out:
# 'blueberry'

# %%
fruits[:]
# Out:
# 'blueberry'

# %%
fruits[:4]
# Out:
# 'blue'

# %%
fruits.upper()
# Out:
# 'BLUEBERRY'

# %%
fruits.count('b'vvvvvv)
# Out:
# 2
